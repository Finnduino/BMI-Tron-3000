# %%
import numpy as np
from scipy.constants import point

from image_processing import *
import cv2
import tqdm
import os

PATH = "floor_1.pdf"
Image.MAX_IMAGE_PIXELS = None

# %%
opencv_image = floor_plan_to_opencv_image(PATH)

opencv_image.shape
# Out:
# (17542, 16542, 3)

# %%
def compress(image, factor=10):
    height, width = image.shape
    scaled_height = height // factor
    scaled_width = width // factor
    result = np.zeros((scaled_height, scaled_width))

    for result_i in tqdm.trange(scaled_height):

        # # once again, sliding window
        # # initial
        # current = 0
        # 
        # for original_i in range(result_i * factor, min((result_i + 1) * (factor + 1), height)):
        #         for original_j in range(min(result_j * (factor + 1), width)):
        #             current += image[original_i, original_j]

        for result_j in range(scaled_width):
            # print(result_i * factor, min((result_i + 1) * factor, height))
            # print(result_j * factor, min((result_j + 1) * factor, width))
            cnt = 0
            for original_i in range(result_i * factor, min((result_i + 1) * factor, height)):
                for original_j in range(result_j * factor, min((result_j + 1) * factor, width)):
                    cnt += (image[original_i, original_j] == 0)
            result[result_i, result_j] = 255 - (255 * cnt) // (factor * factor)

    return result

# %%
# scaled_image = compress(main_image)
# cv.imwrite("IMAGES/scaled.png", scaled_image)

# %%
# def process_image(img):
#     # Convert image to grayscale
#     # gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     
#     # Apply a slight Gaussian blur to reduce noise
#     blurred = cv2.GaussianBlur(img, (3, 3), 0)
#     
#     # Invert the image (so lines are white on black background)
#     inverted = cv2.bitwise_not(blurred)
#     
#     # Calculate local density using a moving window
#     window_size = 15  # Adjust this size for better results
#     kernel = np.ones((window_size, window_size), np.uint8)
#     density_map = cv2.filter2D(inverted, -1, kernel)
#     
#     # Normalize the density map for better contrast
#     normalized = cv2.normalize(density_map, None, 0, 255, cv2.NORM_MINMAX)
#     
#     # Convert to uint8 format for display
#     normalized = np.uint8(normalized)
#     
#     # inverted = cv.bitwise_not(normalized)
#     
#     return inverted

# %%
# scaled_image = process_image(main_image)
# 
# cv.imwrite("IMAGES/scaled.png", scaled_image)

# %%
def transform_architectural_drawing(img, output_path):
    """
    Transform an architectural drawing to a higher contrast, simplified version
    
    Parameters:
    image_path (str): Path to the input image
    output_path (str): Path to save the processed image
    """
    # Read the image in grayscale

    if img is None:
        raise ValueError("Could not load the image")

    # Apply preprocessing steps
    # 1. Denoise the image
    denoised = cv2.fastNlMeansDenoising(img)

    # 2. Increase contrast using adaptive histogram equalization
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    contrast_enhanced = clahe.apply(denoised)

    # 3. Apply threshold to make it more binary-like
    _, binary = cv2.threshold(contrast_enhanced, 200, 255, cv2.THRESH_BINARY)

    # 4. Clean up small noise using morphological operations
    kernel = np.ones((2, 2), np.uint8)
    cleaned = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)

    # 5. Enhance lines
    edges = cv2.Canny(cleaned, 50, 150)
    dilated_edges = cv2.dilate(edges, kernel, iterations=1)

    # 6. Combine the binary image with enhanced edges
    result = cv2.bitwise_and(cleaned, cleaned, mask=cv2.bitwise_not(dilated_edges))

    # Save the result
    cv2.imwrite(output_path, result)

    return result

# %%
# def get_neighborhood(i, sz, bound):
#     return i, min(i + sz, bound)
# 
# def non_linear_filter(image, kernel_size=3, fraction=2):
#     # Get the height and width of the image
#     height, width = image.shape
# 
#     # Create an output image initialized to zeros
#     output_image = np.zeros_like(image)
# 
#     # Iterate over each pixel in the original image
#     for i in tqdm.trange(height):
#         # implement sliding window
# 
#         # initial state
#         # current_black = 0
#         # for ik in range(*get_neighborhood(i, kernel_size, height)):
#         #     for jk in range(*get_neighborhood(0, kernel_size, width)):
#         #         if image[ik, jk] == 0:
#         #             current_black += 1
# 
#         for j in range(1, width):
#             # Extract the kernel window
#             # cross does not work that well as there are diagonal sections
#             kernel_window = []
#             # what if we try give more weight to diagonal thingies?
#             for ik in range(*get_neighborhood(i, kernel_size, height)):
#                 for jk in range(*get_neighborhood(j, kernel_size, width)):
#                     multiplier = abs(ik - i) / max(1, abs(jk - j)) + 1
#                     # if abs(ik - i) == abs(jk - j): # on diagonal
#                     #     multiplier = 2
#                     kernel_window.append((image[ik, jk], multiplier))
# 
# 
#             # Count the number of black pixels in the window
#             current_black = sum(map(lambda x: x[1] if x[0] == 0 else 0, kernel_window))
# 
#             # Determine if more than half the pixels are black
#             threshold = len(kernel_window) / fraction
# 
#             # for ik in range(*get_neighborhood(i, kernel_size, height)):
#             #     # subtract previous
#             #     if image[ik, j - 1] == 0:
#             #         current_black -= 1
#             #     # add current
#             #     if j + kernel_size - 1 < width and image[ik, j + kernel_size - 1] == 0:
#             #         current_black += 1
#             # 
#             # threshold = kernel_size * kernel_size / fraction  # incorrect for edge cases, but whatever
#             output_image[i, j] = 0 if current_black > threshold else 255
# 
#     return output_image
# 
# 
# def soft_max_kernel(image, kernel_size, fraction, f=False):
#     filename = f"IMAGES/default-test-identify{kernel_size}-{fraction}.png"
#     if os.path.isfile(filename) and not f:
#         print("warning! file already exists! pass f flag if you want to overwrite it")
#         return False, None
#     scanned = non_linear_filter(image, kernel_size, fraction)
#     return cv.imwrite(filename, scanned), scanned

# %%
# f, res = soft_max_kernel(main_image, 10, 10, True)
# f

# %%
no_details = remove_page_details(opencv_image, eps=10, min_samples=30)
no_details.shape
# Out:
# 100%|██████████| 3508/3508 [00:01<00:00, 2291.25it/s]
# 446
# [(np.int64(6), 174469), (np.int64(-1), 42567), (np.int64(23), 7695), (np.int64(66), 727), (np.int64(223), 595), (np.int64(0), 469), (np.int64(169), 443), (np.int64(414), 395), (np.int64(433), 387), (np.int64(41), 350)]
# (3508, 3308)

# %%
# def get_neighborhood(i, sz, bound):
#     return i, min(i + sz, bound)
# 
# def non_linear_filter(image, kernel_size=3, fraction=2):
#     # Get the height and width of the image
#     height, width = image.shape
# 
#     # Create an output image initialized to zeros
#     output_image = np.zeros_like(image)
# 
#     # Iterate over each pixel in the original image
#     for i in tqdm.trange(height):
#         # implement sliding window
# 
#         # initial state
#         # current_black = 0
#         # for ik in range(*get_neighborhood(i, kernel_size, height)):
#         #     for jk in range(*get_neighborhood(0, kernel_size, width)):
#         #         if image[ik, jk] == 0:
#         #             current_black += 1
# 
#         for j in range(1, width):
#             # Extract the kernel window
#             # cross does not work that well as there are diagonal sections
#             kernel_window = []
#             # what if we try give more weight to diagonal thingies?
#             for ik in range(*get_neighborhood(i, kernel_size, height)):
#                 for jk in range(*get_neighborhood(j, kernel_size, width)):
#                     # multiplier = abs(ik - i) / max(1, abs(jk - j)) + 1
#                     # if abs(ik - i) == abs(jk - j): # on diagonal
#                     #     multiplier = 2
#                     multiplier = 1
#                     kernel_window.append((image[ik, jk], multiplier))
# 
# 
#             # Count the number of black pixels in the window
#             current_black = sum(map(lambda x: x[1] if x[0] == 0 else 0, kernel_window))
# 
#             # Determine if more than half the pixels are black
#             threshold = len(kernel_window) / fraction
# 
#             # for ik in range(*get_neighborhood(i, kernel_size, height)):
#             #     # subtract previous
#             #     if image[ik, j - 1] == 0:
#             #         current_black -= 1
#             #     # add current
#             #     if j + kernel_size - 1 < width and image[ik, j + kernel_size - 1] == 0:
#             #         current_black += 1
#             # 
#             # threshold = kernel_size * kernel_size / fraction  # incorrect for edge cases, but whatever
#             output_image[i, j] = 0 if current_black > threshold else 255
# 
#     return output_image
# 
# 
# def soft_max_kernel(image, kernel_size, fraction, f=False):
#     filename = f"IMAGES/post-clustering-softmax{kernel_size}-{fraction}.png"
#     if os.path.isfile(filename) and not f:
#         print("warning! file already exists! pass f flag if you want to overwrite it")
#         return False, None
#     scanned = non_linear_filter(image, kernel_size, fraction)
#     return cv.imwrite(filename, scanned), scanned

# %%
# f, res = soft_max_kernel(no_details, 5, 3, True)
# f

# %%
def extend_line(line, height, width):
    p1 = np.array(line[0:2])
    p2 = np.array(line[2:4])

    if (p2 - p1)[0] == 0:
        p1[1] = 0
        p2[1] = height
    else:
        k = (p2[1] - p1[1]) / (p2[0] - p1[0])
        b = p2[1] - p2[0] * k

        p1[0] = 0
        p1[1] = b

        p2[0] = width
        p2[1] = k * p2[0] + b
    return *p1, *p2

# %%
# try to find lines
def find_lines(image):
    HALF_LENGTH = 1000
    segments = []
    points = []
    output = cv.cvtColor(image, cv.COLOR_GRAY2BGR)  # assumes image in grayscale
    # edges = cv.Canny(image, 1, 50, None, 3)
    # lines = cv.HoughLines(edges, 1, np.pi / 180, threshold=200)
    # # return lines
    # for line in lines:
    #     rho = line[0][0]
    #     theta = line[0][1]
    #     a = np.cos(theta)
    #     b = np.sin(theta)
    #     x0 = a * rho
    #     y0 = b * rho
    #     pt1 = (int(x0 + HALF_LENGTH * (-b)), int(y0 + HALF_LENGTH * a))
    #     pt2 = (int(x0 - HALF_LENGTH * (-b)), int(y0 - HALF_LENGTH * a))
    #     cv.line(output, pt1, pt2, (0, 0, 255), 1, cv.LINE_AA)
    h, w = image.shape
    edges = cv.Canny(image, 50, 150, apertureSize=3)
    lines = cv.HoughLinesP(edges, 1, np.pi / 180, threshold=100, minLineLength=50, maxLineGap=10)
    for line in lines:
        # x1, y1, x2, y2 = extend_line(line[0], h, w)
        x1, y1, x2, y2 = line[0]
        # segments.append(line[0])
        points.append(np.array((x1, y1)))
        points.append(np.array((x2, y2)))
        segments.append(line[0])
        cv.line(output, (x1, y1), (x2, y2), (0, 0, 255), 1)
    return points, segments, output

# %%
pts, segs, lines_no_details = find_lines(no_details.astype(np.uint8))
print(lines_no_details.shape)
cv.imwrite("IMAGES/lines_no_details.png", lines_no_details)
# Out:
# (3508, 3308, 3)
# True

# %%
pts
# Out:
# [array([ 912, 3348], dtype=int32),
#  array([ 912, 1604], dtype=int32),
#  array([1764, 2437], dtype=int32),
#  array([1764, 1000], dtype=int32),
#  array([1769, 3416], dtype=int32),
#  array([1769, 3192], dtype=int32),
#  array([1780, 2810], dtype=int32),
#  array([1780, 2477], dtype=int32),
#  array([1755, 2108], dtype=int32),
#  array([1755, 1654], dtype=int32),
#  array([1778, 2121], dtype=int32),
#  array([1778, 1642], dtype=int32),
#  array([1753, 2108], dtype=int32),
#  array([1753, 1654], dtype=int32),
#  array([1766, 2796], dtype=int32),
#  array([1766, 2478], dtype=int32),
#  array([ 930, 2674], dtype=int32),
#  array([ 930, 1571], dtype=int32),
#  array([1771, 1417], dtype=int32),
#  array([1771, 1000], dtype=int32),
#  array([ 928, 3195], dtype=int32),
#  array([ 928, 3121], dtype=int32),
#  array([ 674, 3346], dtype=int32),
#  array([1797, 3346], dtype=int32),
#  array([1622, 1246], dtype=int32),
#  array([1622, 1016], dtype=int32),
#  array([ 675, 3348], dtype=int32),
#  array([1742, 3348], dtype=int32),
#  array([1624, 2064], dtype=int32),
#  array([1624, 1700], dtype=int32),
#  array([ 101, 3235], dtype=int32),
#  array([ 910, 2426], dtype=int32),
#  array([ 936, 2672], dtype=int32),
#  array([ 936, 1589], dtype=int32),
#  array([  19, 2926], dtype=int32),
#  array([ 908, 2037], dtype=int32),
#  array([ 945, 3343], dtype=int32),
#  array([1780, 3343], dtype=int32),
#  array([  19, 2475], dtype=int32),
#  array([ 925, 1569], dtype=int32),
#  array([1228, 2776], dtype=int32),
#  array([1797, 2776], dtype=int32),
#  array([  21, 1762], dtype=int32),
#  array([  21, 1594], dtype=int32),
#  array([  19, 2469], dtype=int32),
#  array([ 895, 1593], dtype=int32),
#  array([ 910, 3352], dtype=int32),
#  array([ 910, 2380], dtype=int32),
#  array([ 900, 3355], dtype=int32),
#  array([ 900, 2668], dtype=int32),
#  array([  19, 3337], dtype=int32),
#  array([ 909, 2447], dtype=int32),
#  array([ 949, 2687], dtype=int32),
#  array([ 949, 1583], dtype=int32),
#  array([  19, 3377], dtype=int32),
#  array([ 906, 2490], dtype=int32),
#  array([  19, 2489], dtype=int32),
#  array([ 885, 1623], dtype=int32),
#  array([ 928, 2672], dtype=int32),
#  array([ 928, 1584], dtype=int32),
#  array([  19, 3055], dtype=int32),
#  array([  19, 2877], dtype=int32),
#  array([ 504, 2774], dtype=int32),
#  array([ 675, 2774], dtype=int32),
#  array([  19, 2499], dtype=int32),
#  array([ 903, 1615], dtype=int32),
#  array([ 829, 1739], dtype=int32),
#  array([ 829, 1591], dtype=int32),
#  array([ 831, 2608], dtype=int32),
#  array([ 831, 2398], dtype=int32),
#  array([  19, 3327], dtype=int32),
#  array([ 918, 2428], dtype=int32),
#  array([ 947, 2687], dtype=int32),
#  array([ 947, 1581], dtype=int32),
#  array([  21, 2938], dtype=int32),
#  array([ 913, 2046], dtype=int32),
#  array([  19, 2515], dtype=int32),
#  array([ 909, 1625], dtype=int32),
#  array([  19, 2479], dtype=int32),
#  array([ 915, 1583], dtype=int32),
#  array([  21, 2948], dtype=int32),
#  array([ 906, 2063], dtype=int32),
#  array([1730, 1204], dtype=int32),
#  array([1780, 1154], dtype=int32),
#  array([  19, 2505], dtype=int32),
#  array([ 910, 1614], dtype=int32),
#  array([  19, 2509], dtype=int32),
#  array([ 910, 1618], dtype=int32),
#  array([  19, 3367], dtype=int32),
#  array([ 908, 2478], dtype=int32),
#  array([  19, 2495], dtype=int32),
#  array([ 920, 1594], dtype=int32),
#  array([  19, 2485], dtype=int32),
#  array([ 901, 1603], dtype=int32),
#  array([  19, 2519], dtype=int32),
#  array([ 918, 1620], dtype=int32),
#  array([  19, 3371], dtype=int32),
#  array([ 919, 2471], dtype=int32),
#  array([  21, 2934], dtype=int32),
#  array([ 910, 2045], dtype=int32),
#  array([  19, 2525], dtype=int32),
#  array([ 909, 1635], dtype=int32),
#  array([  21, 2944], dtype=int32),
#  array([ 919, 2046], dtype=int32),
#  array([1885, 2350], dtype=int32),
#  array([1885, 2092], dtype=int32),
#  array([  19, 2465], dtype=int32),
#  array([ 889, 1595], dtype=int32),
#  array([1757, 1562], dtype=int32),
#  array([1757, 1411], dtype=int32),
#  array([  19, 3351], dtype=int32),
#  array([ 909, 2461], dtype=int32),
#  array([  21, 2904], dtype=int32),
#  array([ 935, 1990], dtype=int32),
#  array([  21, 2898], dtype=int32),
#  array([ 909, 2010], dtype=int32),
#  array([  19, 2539], dtype=int32),
#  array([ 831, 1727], dtype=int32),
#  array([1759, 2948], dtype=int32),
#  array([1759, 2509], dtype=int32),
#  array([ 125, 2353], dtype=int32),
#  array([ 888, 1590], dtype=int32),
#  array([  19, 2044], dtype=int32),
#  array([ 634, 1429], dtype=int32),
#  array([  19, 2108], dtype=int32),
#  array([ 673, 1454], dtype=int32),
#  array([  21, 2958], dtype=int32),
#  array([ 919, 2060], dtype=int32),
#  array([  19, 3341], dtype=int32),
#  array([ 918, 2442], dtype=int32),
#  array([  21, 2928], dtype=int32),
#  array([ 918, 2031], dtype=int32),
#  array([  19, 2104], dtype=int32),
#  array([ 671, 1452], dtype=int32),
#  array([  19, 3381], dtype=int32),
#  array([ 909, 2491], dtype=int32),
#  array([  21, 2964], dtype=int32),
#  array([ 814, 2171], dtype=int32),
#  array([  21, 2914], dtype=int32),
#  array([ 910, 2025], dtype=int32),
#  array([ 945, 3332], dtype=int32),
#  array([1780, 3332], dtype=int32),
#  array([  19, 3347], dtype=int32),
#  array([ 906, 2460], dtype=int32),
#  array([  19, 3331], dtype=int32),
#  array([ 919, 2431], dtype=int32),
#  array([  21, 2968], dtype=int32),
#  array([ 816, 2173], dtype=int32),
#  array([  21, 2894], dtype=int32),
#  array([ 908, 2007], dtype=int32),
#  array([  19, 3401], dtype=int32),
#  array([ 794, 2626], dtype=int32),
#  array([ 123, 2351], dtype=int32),
#  array([ 886, 1588], dtype=int32),
#  array([  19, 3391], dtype=int32),
#  array([ 903, 2507], dtype=int32),
#  array([  21, 2954], dtype=int32),
#  array([ 908, 2067], dtype=int32),
#  array([  19, 2535], dtype=int32),
#  array([ 819, 1735], dtype=int32),
#  array([  21, 2918], dtype=int32),
#  array([ 906, 2033], dtype=int32),
#  array([ 124, 2781], dtype=int32),
#  array([ 909, 1996], dtype=int32),
#  array([ 103, 3237], dtype=int32),
#  array([ 909, 2431], dtype=int32),
#  array([  21, 2908], dtype=int32),
#  array([ 906, 2023], dtype=int32),
#  array([  19, 2118], dtype=int32),
#  array([ 674, 1463], dtype=int32),
#  array([  19, 3357], dtype=int32),
#  array([ 909, 2467], dtype=int32),
#  array([1768, 3035], dtype=int32),
#  array([1768, 2796], dtype=int32),
#  array([  19, 2529], dtype=int32),
#  array([ 907, 1641], dtype=int32),
#  array([  19, 3407], dtype=int32),
#  array([ 700, 2726], dtype=int32),
#  array([  19, 3387], dtype=int32),
#  array([ 920, 2486], dtype=int32),
#  array([ 205, 2690], dtype=int32),
#  array([ 932, 1963], dtype=int32),
#  array([ 207, 2692], dtype=int32),
#  array([ 934, 1965], dtype=int32),
#  array([ 314, 2571], dtype=int32),
#  array([ 908, 1977], dtype=int32),
#  array([ 205, 3125], dtype=int32),
#  array([ 906, 2424], dtype=int32),
#  array([  19, 3397], dtype=int32),
#  array([ 792, 2624], dtype=int32),
#  array([  21, 2978], dtype=int32),
#  array([ 727, 2272], dtype=int32),
#  array([ 126, 2783], dtype=int32),
#  array([ 918, 1991], dtype=int32),
#  array([1887, 3037], dtype=int32),
#  array([1887, 2788], dtype=int32),
#  array([ 303, 3488], dtype=int32),
#  array([ 895, 2896], dtype=int32),
#  array([  19, 3361], dtype=int32),
#  array([ 908, 2472], dtype=int32),
#  array([  19, 1673], dtype=int32),
#  array([ 520, 1172], dtype=int32),
#  array([  19, 2094], dtype=int32),
#  array([ 664, 1449], dtype=int32),
#  array([  19, 2084], dtype=int32),
#  array([ 686, 1417], dtype=int32),
#  array([  19, 2124], dtype=int32),
#  array([ 651, 1492], dtype=int32),
#  array([  19, 2064], dtype=int32),
#  array([ 646, 1437], dtype=int32),
#  array([ 323, 3488], dtype=int32),
#  array([ 896, 2915], dtype=int32),
#  array([  21, 2984], dtype=int32),
#  array([ 626, 2379], dtype=int32),
#  array([  19, 2114], dtype=int32),
#  array([ 672, 1461], dtype=int32),
#  array([  19, 2058], dtype=int32),
#  array([ 639, 1438], dtype=int32),
#  array([ 303, 2151], dtype=int32),
#  array([ 901, 1553], dtype=int32),
#  array([  19, 2068], dtype=int32),
#  array([ 676, 1411], dtype=int32),
#  array([ 203, 3123], dtype=int32),
#  array([ 921, 2405], dtype=int32),
#  array([  19, 2545], dtype=int32),
#  array([ 732, 1832], dtype=int32),
#  array([1521, 1919], dtype=int32),
#  array([1575, 1865], dtype=int32),
#  array([  21, 2988], dtype=int32),
#  array([ 628, 2381], dtype=int32),
#  array([  19, 3411], dtype=int32),
#  array([ 702, 2728], dtype=int32),
#  array([ 353, 3488], dtype=int32),
#  array([ 890, 2951], dtype=int32),
#  array([  19, 2038], dtype=int32),
#  array([ 649, 1408], dtype=int32),
#  array([ 212, 2256], dtype=int32),
#  array([ 880, 1588], dtype=int32),
#  array([1188, 2369], dtype=int32),
#  array([1797, 2369], dtype=int32),
#  array([  19, 2074], dtype=int32),
#  array([ 683, 1410], dtype=int32),
#  array([ 210, 2254], dtype=int32),
#  array([ 877, 1587], dtype=int32),
#  array([  21, 2974], dtype=int32),
#  array([ 725, 2270], dtype=int32),
#  array([  19, 2034], dtype=int32),
#  array([ 622, 1431], dtype=int32),
#  array([ 284, 3463], dtype=int32),
#  array([ 897, 2850], dtype=int32),
#  array([ 868, 2371], dtype=int32),
#  array([1130, 2371], dtype=int32),
#  array([  19, 2054], dtype=int32),
#  array([ 638, 1435], dtype=int32),
#  array([  19, 2549], dtype=int32),
#  array([ 734, 1834], dtype=int32),
#  array([  19, 1643], dtype=int32),
#  array([ 530, 1132], dtype=int32),
#  array([  19, 2078], dtype=int32),
#  array([ 654, 1443], dtype=int32),
#  array([ 291, 3486], dtype=int32),
#  array([ 897, 2880], dtype=int32),
#  array([ 293, 3488], dtype=int32),
#  array([ 895, 2886], dtype=int32),
#  array([  19, 1637], dtype=int32),
#  array([ 519, 1137], dtype=int32),
#  array([ 313, 3488], dtype=int32),
#  array([ 895, 2906], dtype=int32),
#  array([1402, 3044], dtype=int32),
#  array([1402, 2500], dtype=int32),
#  array([ 343, 3488], dtype=int32),
#  array([ 895, 2936], dtype=int32),
#  array([  19, 1617], dtype=int32),
#  array([ 514, 1122], dtype=int32),
#  array([  19, 2128], dtype=int32),
#  array([ 651, 1496], dtype=int32),
#  array([ 283, 3488], dtype=int32),
#  array([ 895, 2876], dtype=int32),
#  array([ 316, 2573], dtype=int32),
#  array([ 909, 1980], dtype=int32),
#  array([  19, 1663], dtype=int32),
#  array([ 575, 1107], dtype=int32),
#  array([  19, 2088], dtype=int32),
#  array([ 663, 1444], dtype=int32),
#  array([  19, 1667], dtype=int32),
#  array([ 526, 1160], dtype=int32),
#  array([  19, 3441], dtype=int32),
#  array([ 424, 3036], dtype=int32),
#  array([ 276, 3481], dtype=int32),
#  array([ 939, 2818], dtype=int32),
#  array([  19, 2555], dtype=int32),
#  array([ 628, 1946], dtype=int32),
#  array([ 333, 3488], dtype=int32),
#  array([ 895, 2926], dtype=int32),
#  array([  19, 2098], dtype=int32),
#  array([ 665, 1452], dtype=int32),
#  array([ 341, 3486], dtype=int32),
#  array([ 950, 2877], dtype=int32),
#  array([  19, 2559], dtype=int32),
#  array([ 630, 1948], dtype=int32),
#  array([1379, 3099], dtype=int32),
#  array([1379, 3003], dtype=int32),
#  array([ 304, 2154], dtype=int32),
#  array([ 904, 1554], dtype=int32),
#  array([1381, 2512], dtype=int32),
#  array([1381, 2344], dtype=int32),
#  array([ 297, 3019], dtype=int32),
#  array([ 908, 2408], dtype=int32),
#  array([ 128, 1919], dtype=int32),
#  array([ 627, 1420], dtype=int32),
#  array([  19, 2138], dtype=int32),
#  array([ 530, 1627], dtype=int32),
#  array([ 380, 2926], dtype=int32),
#  array([ 918, 2388], dtype=int32),
#  array([  19, 3421], dtype=int32),
#  array([ 619, 2821], dtype=int32),
#  array([ 286, 3465], dtype=int32),
#  array([ 895, 2856], dtype=int32),
#  array([  19, 2048], dtype=int32),
#  array([ 667, 1400], dtype=int32),
#  array([ 278, 3483], dtype=int32),
#  array([ 902, 2859], dtype=int32),
#  array([1188, 1883], dtype=int32),
#  array([1798, 1883], dtype=int32),
#  array([  19, 1647], dtype=int32),
#  array([ 534, 1132], dtype=int32),
#  array([ 331, 3486], dtype=int32),
#  array([ 898, 2919], dtype=int32),
#  array([ 321, 3486], dtype=int32),
#  array([ 897, 2910], dtype=int32),
#  array([  19, 1613], dtype=int32),
#  array([ 512, 1120], dtype=int32),
#  array([  19, 2134], dtype=int32),
#  array([ 528, 1625], dtype=int32),
#  array([ 407, 2472], dtype=int32),
#  array([ 919, 1960], dtype=int32),
#  array([ 351, 3486], dtype=int32),
#  array([ 897, 2940], dtype=int32),
#  array([ 412, 2036], dtype=int32),
#  array([ 870, 1578], dtype=int32),
#  array([  19, 1653], dtype=int32),
#  array([ 529, 1143], dtype=int32),
#  array([  19, 1707], dtype=int32),
#  array([ 452, 1274], dtype=int32),
#  array([ 892, 1881], dtype=int32),
#  array([1130, 1881], dtype=int32),
#  array([  19, 2144], dtype=int32),
#  array([ 460, 1703], dtype=int32),
#  array([  21, 2998], dtype=int32),
#  array([ 519, 2500], dtype=int32),
#  array([  19, 1703], dtype=int32),
#  array([ 548, 1174], dtype=int32),
#  array([ 281, 3486], dtype=int32),
#  array([ 937, 2830], dtype=int32),
#  array([  19, 1687], dtype=int32),
#  array([ 489, 1217], dtype=int32),
#  array([1391, 2686], dtype=int32),
#  array([1391, 2605], dtype=int32),
#  array([ 311, 3486], dtype=int32),
#  array([ 950, 2847], dtype=int32),
#  array([  19, 1627], dtype=int32),
#  array([ 513, 1133], dtype=int32),
#  array([ 933, 2045], dtype=int32),
#  array([ 933, 1573], dtype=int32),
#  array([  19, 1697], dtype=int32),
#  array([ 472, 1244], dtype=int32),
#  array([  19, 1693], dtype=int32),
#  array([ 547, 1165], dtype=int32),
#  array([1743, 1085], dtype=int32),
#  array([1743,  972], dtype=int32),
#  array([ 301, 3486], dtype=int32),
#  array([ 898, 2889], dtype=int32),
#  array([ 126, 1917], dtype=int32),
#  array([ 653, 1390], dtype=int32),
#  array([  19, 3417], dtype=int32),
#  array([ 617, 2819], dtype=int32),
#  array([  19, 3431], dtype=int32),
#  array([ 517, 2933], dtype=int32),
#  array([ 299, 3021], dtype=int32),
#  array([ 918, 2402], dtype=int32),
#  array([1206, 2363], dtype=int32),
#  array([1735, 2363], dtype=int32),
#  array([1758, 2113], dtype=int32),
#  array([1758, 1654], dtype=int32),
#  array([ 379, 3358], dtype=int32),
#  array([ 973, 2764], dtype=int32),
#  array([ 405, 2470], dtype=int32),
#  array([ 909, 1966], dtype=int32),
#  array([  19, 1657], dtype=int32),
#  array([ 585, 1091], dtype=int32),
#  array([1334, 1387], dtype=int32),
#  array([1741, 1387], dtype=int32),
#  array([1881, 3039], dtype=int32),
#  array([1881, 2796], dtype=int32),
#  array([ 927, 3195], dtype=int32),
#  array([ 927, 2756], dtype=int32),
#  array([  19, 2148], dtype=int32),
#  array([ 462, 1705], dtype=int32),
#  array([  19, 1623], dtype=int32),
#  array([ 505, 1137], dtype=int32),
#  array([ 948, 2687], dtype=int32),
#  array([ 948, 1584], dtype=int32),
#  array([1741, 1240], dtype=int32),
#  array([1741, 1097], dtype=int32),
#  array([ 410, 2034], dtype=int32),
#  array([ 854, 1590], dtype=int32),
#  array([ 229, 1804], dtype=int32),
#  array([ 615, 1418], dtype=int32),
#  array([  19, 3427], dtype=int32),
#  array([ 515, 2931], dtype=int32),
#  array([ 314, 1713], dtype=int32),
#  array([ 613, 1414], dtype=int32),
#  array([ 937, 2782], dtype=int32),
#  array([1151, 2782], dtype=int32),
#  array([  19, 1683], dtype=int32),
#  array([ 542, 1160], dtype=int32),
#  array([ 935, 1873], dtype=int32),
#  array([ 935, 1588], dtype=int32),
#  array([ 914, 3130], dtype=int32),
#  array([ 914, 2748], dtype=int32),
#  array([918, 978], dtype=int32),
#  array([918, 912], dtype=int32),
#  array([  19, 1633], dtype=int32),
#  array([ 504, 1148], dtype=int32),
#  array([ 925, 3121], dtype=int32),
#  array([ 925, 2747], dtype=int32),
#  array([434, 690], dtype=int32),
#  array([651, 344], dtype=int32),
#  array([ 482, 2818], dtype=int32),
#  array([ 906, 2394], dtype=int32),
#  array([  21, 3004], dtype=int32),
#  array([ 436, 2589], dtype=int32),
#  array([ 382, 2928], dtype=int32),
#  array([ 909, 2401], dtype=int32),
#  array([ 480, 2816], dtype=int32),
#  array([ 911, 2385], dtype=int32),
#  array([ 932, 2674], dtype=int32),
#  array([ 932, 1887], dtype=int32),
#  array([1334, 1385], dtype=int32),
#  array([1780, 1385], dtype=int32),
#  array([1207, 2361], dtype=int32),
#  array([1735, 2361], dtype=int32),
#  array([  44, 1582], dtype=int32),
#  array([ 508, 1118], dtype=int32),
#  array([  19, 1713], dtype=int32),
#  array([ 463, 1269], dtype=int32),
#  array([458, 626], dtype=int32),
#  array([690, 256], dtype=int32),
#  array([ 494, 2371], dtype=int32),
#  array([ 919, 1946], dtype=int32),
#  array([  19, 1677], dtype=int32),
#  array([ 506, 1190], dtype=int32),
#  array([  19, 2579], dtype=int32),
#  array([ 440, 2158], dtype=int32),
#  array([  19, 3437], dtype=int32),
#  array([ 422, 3034], dtype=int32),
#  array([  19, 2154], dtype=int32),
#  array([ 337, 1836], dtype=int32),
#  array([1389, 2536], dtype=int32),
#  array([1389, 2371], dtype=int32),
#  array([1208, 1891], dtype=int32),
#  array([1736, 1891], dtype=int32),
#  array([  21, 2994], dtype=int32),
#  array([ 517, 2498], dtype=int32),
#  array([ 934, 2674], dtype=int32),
#  array([ 934, 1571], dtype=int32),
#  array([1769, 1417], dtype=int32),
#  array([1769,  999], dtype=int32),
#  array([  19, 1727], dtype=int32),
#  array([ 363, 1383], dtype=int32),
#  array([  19, 2565], dtype=int32),
#  array([ 518, 2066], dtype=int32),
#  array([ 945, 3341], dtype=int32),
#  array([1780, 3341], dtype=int32),
#  array([ 311, 1712], dtype=int32),
#  array([ 607, 1416], dtype=int32),
#  array([  19, 1717], dtype=int32),
#  array([ 465, 1271], dtype=int32),
#  array([403, 731], dtype=int32),
#  array([645, 344], dtype=int32),
#  array([650, 326], dtype=int32),
#  array([846, 449], dtype=int32),
#  array([  21, 3008], dtype=int32),
#  array([ 438, 2591], dtype=int32),
#  array([  19, 2569], dtype=int32),
#  array([ 521, 2067], dtype=int32),
#  array([232, 985], dtype=int32),
#  array([493, 567], dtype=int32),
#  array([  42, 1580], dtype=int32),
#  array([ 507, 1115], dtype=int32),
#  array([ 129, 1487], dtype=int32),
#  array([ 501, 1115], dtype=int32),
#  array([1245, 2784], dtype=int32),
#  array([1381, 2784], dtype=int32),
#  array([ 989, 2440], dtype=int32),
#  array([ 989, 2344], dtype=int32),
#  array([1206, 1889], dtype=int32),
#  array([1737, 1889], dtype=int32),
#  array([  19, 1723], dtype=int32),
#  array([ 361, 1381], dtype=int32),
#  array([1733, 1928], dtype=int32),
#  array([1733, 1863], dtype=int32),
#  array([ 231, 1806], dtype=int32),
#  array([ 617, 1420], dtype=int32),
#  array([ 381, 3360], dtype=int32),
#  array([ 895, 2846], dtype=int32),
#  array([  19, 2158], dtype=int32),
#  array([ 339, 1838], dtype=int32),
#  array([ 918, 3123], dtype=int32),
#  array([ 918, 2747], dtype=int32),
#  array([1883, 2350], dtype=int32),
#  array([1883, 2102], dtype=int32),
#  array([ 945, 3334], dtype=int32),
#  array([1780, 3334], dtype=int32),
#  array([1762, 1886], dtype=int32),
#  array([1762, 1654], dtype=int32),
#  array([1405, 2379], dtype=int32),
#  array([1733, 2379], dtype=int32),
#  array([  19, 2575], dtype=int32),
#  array([ 438, 2156], dtype=int32),
#  array([ 504, 1930], dtype=int32),
#  array([ 888, 1546], dtype=int32),
#  array([371, 771], dtype=int32),
#  array([618, 377], dtype=int32),
#  array([ 496, 2373], dtype=int32),
#  array([ 906, 1963], dtype=int32),
#  array([ 908, 2052], dtype=int32),
#  array([ 908, 1872], dtype=int32),
#  array([1760, 1886], dtype=int32),
#  array([1760, 1654], dtype=int32),
#  array([  19, 2168], dtype=int32),
#  array([ 245, 1942], dtype=int32),
#  array([ 137, 1135], dtype=int32),
#  array([312, 856], dtype=int32),
#  array([1726, 1393], dtype=int32),
#  array([1790, 1393], dtype=int32),
#  array([ 898, 3355], dtype=int32),
#  array([ 898, 2874], dtype=int32),
#  array([ 127, 1485], dtype=int32),
#  array([ 492, 1120], dtype=int32),
#  array([ 474, 3257], dtype=int32),
#  array([ 895, 2836], dtype=int32),
#  array([1726, 1395], dtype=int32),
#  array([1790, 1395], dtype=int32),
#  array([406, 724], dtype=int32),
#  array([605, 406], dtype=int32),
#  array([272, 915], dtype=int32),
#  array([640, 327], dtype=int32),
#  array([ 197, 1047], dtype=int32),
#  array([439, 661], dtype=int32),
#  array([ 472, 3255], dtype=int32),
#  array([ 898, 2829], dtype=int32),
#  array([1780, 3416], dtype=int32),
#  array([1780, 3178], dtype=int32),
#  array([309, 892], dtype=int32),
#  array([445, 675], dtype=int32),
#  array([ 587, 2699], dtype=int32),
#  array([ 917, 2369], dtype=int32),
#  array([ 829, 2608], dtype=int32),
#  array([ 829, 2398], dtype=int32),
#  array([ 909, 2004], dtype=int32),
#  array([ 909, 1602], dtype=int32),
#  array([ 919, 3123], dtype=int32),
#  array([ 919, 2763], dtype=int32),
#  array([ 361, 3486], dtype=int32),
#  array([ 783, 3064], dtype=int32),
#  array([ 577, 3144], dtype=int32),
#  array([ 895, 2826], dtype=int32),
#  array([ 920, 3330], dtype=int32),
#  array([ 920, 3157], dtype=int32),
#  array([1735, 2412], dtype=int32),
#  array([1735, 2344], dtype=int32),
#  array([ 363, 3488], dtype=int32),
#  array([ 785, 3066], dtype=int32),
#  array([1623, 1847], dtype=int32),
#  array([1697, 1773], dtype=int32),
#  array([ 931, 2674], dtype=int32),
#  array([ 931, 1887], dtype=int32),
#  array([  19, 2585], dtype=int32),
#  array([ 328, 2276], dtype=int32),
#  array([ 938, 2661], dtype=int32),
#  array([ 938, 2514], dtype=int32),
#  array([  19, 1737], dtype=int32),
#  array([ 257, 1499], dtype=int32),
#  array([  19, 3447], dtype=int32),
#  array([ 325, 3141], dtype=int32),
#  array([ 589, 2266], dtype=int32),
#  array([ 906, 1949], dtype=int32),
#  array([ 991, 2440], dtype=int32),
#  array([ 991, 2344], dtype=int32),
#  array([ 923, 3226], dtype=int32),
#  array([ 923, 2747], dtype=int32),
#  array([ 371, 3486], dtype=int32),
#  array([ 697, 3160], dtype=int32),
#  array([1757, 2948], dtype=int32),
#  array([1757, 2503], dtype=int32),
#  array([ 591, 2268], dtype=int32),
#  array([ 907, 1952], dtype=int32),
#  array([1761, 3109], dtype=int32),
#  array([1761, 3047], dtype=int32),
#  array([1049, 3121], dtype=int32),
#  array([1413, 3121], dtype=int32),
#  array([ 589, 2701], dtype=int32),
#  array([ 908, 2382], dtype=int32),
#  array([ 962, 1940], dtype=int32),
#  array([ 962, 1854], dtype=int32),
#  array([  21, 3018], dtype=int32),
#  array([ 328, 2711], dtype=int32),
#  array([  19, 2589], dtype=int32),
#  array([ 330, 2278], dtype=int32),
#  array([ 960, 2784], dtype=int32),
#  array([ 960, 2729], dtype=int32),
#  array([1209,  692], dtype=int32),
#  array([1446,  840], dtype=int32),
#  array([ 897, 2774], dtype=int32),
#  array([1164, 2774], dtype=int32),
#  array([1759, 2214], dtype=int32),
#  array([1759, 2158], dtype=int32),
#  array([ 506, 1932], dtype=int32),
#  array([ 862, 1576], dtype=int32),
#  array([1771, 2647], dtype=int32),
#  array([1771, 2591], dtype=int32),
#  array([1054, 3132], dtype=int32),
#  array([1411, 3132], dtype=int32),
#  array([1362, 1400], dtype=int32),
#  array([1780, 1400], dtype=int32),
#  array([ 915, 3128], dtype=int32),
#  array([ 989, 3128], dtype=int32),
#  array([1517, 1374], dtype=int32),
#  array([1780, 1374], dtype=int32),
#  array([1467, 1393], dtype=int32),
#  array([1640, 1393], dtype=int32),
#  array([1157,  645], dtype=int32),
#  array([1444,  825], dtype=int32),
#  array([  19, 3451], dtype=int32),
#  array([ 327, 3143], dtype=int32),
#  array([1758, 2412], dtype=int32),
#  array([1759, 2343], dtype=int32),
#  array([ 373, 3488], dtype=int32),
#  array([ 699, 3162], dtype=int32),
#  array([ 241, 1365], dtype=int32),
#  array([ 496, 1110], dtype=int32),
#  array([ 239, 1363], dtype=int32),
#  array([ 486, 1116], dtype=int32),
#  array([1048, 3123], dtype=int32),
#  array([1413, 3123], dtype=int32),
#  array([1337, 1908], dtype=int32),
#  array([1439, 1908], dtype=int32),
#  array([1761, 2804], dtype=int32),
#  array([1761, 2495], dtype=int32),
#  array([1297, 2405], dtype=int32),
#  array([1526, 2405], dtype=int32),
#  array([1766, 1751], dtype=int32),
#  array([1766, 1695], dtype=int32),
#  array([ 900, 2407], dtype=int32),
#  array([1082, 2407], dtype=int32),
#  array([1517, 1376], dtype=int32),
#  array([1755, 1376], dtype=int32),
#  array([1740, 3300], dtype=int32),
#  array([1741, 3231], dtype=int32),
#  array([ 449, 1568], dtype=int32),
#  array([ 639, 1378], dtype=int32),
#  array([  19, 2595], dtype=int32),
#  array([ 243, 2371], dtype=int32),
#  array([ 935, 3325], dtype=int32),
#  array([ 935, 3275], dtype=int32),
#  array([1062, 1395], dtype=int32),
#  array([1130, 1395], dtype=int32),
#  array([1743, 3353], dtype=int32),
#  array([1743, 3193], dtype=int32),
#  array([1757, 3100], dtype=int32),
#  array([1759, 3046], dtype=int32),
#  array([ 229, 1016], dtype=int32),
#  array([440, 679], dtype=int32),
#  array([470, 636], dtype=int32),
#  array([635, 373], dtype=int32),
#  array([1337, 1910], dtype=int32),
#  array([1439, 1910], dtype=int32),
#  array([ 421, 1592], dtype=int32),
#  array([ 598, 1415], dtype=int32),
#  array([1273,  713], dtype=int32),
#  array([1408,  797], dtype=int32),
#  array([1622, 2425], dtype=int32),
#  array([1622, 2337], dtype=int32),
#  array([ 575, 3142], dtype=int32),
#  array([ 897, 2820], dtype=int32),
#  array([  19, 1252], dtype=int32),
#  array([ 134, 1137], dtype=int32),
#  array([  21, 3014], dtype=int32),
#  array([ 326, 2709], dtype=int32),
#  array([1391, 3115], dtype=int32),
#  array([1391, 2990], dtype=int32),
#  array([1627,  926], dtype=int32),
#  array([1763, 1011], dtype=int32),
#  array([ 922, 3141], dtype=int32),
#  array([ 922, 2747], dtype=int32),
#  array([428, 664], dtype=int32),
#  array([594, 399], dtype=int32),
#  array([ 672, 2608], dtype=int32),
#  array([ 906, 2374], dtype=int32),
#  array([ 670, 2606], dtype=int32),
#  array([ 919, 2357], dtype=int32),
#  array([  19, 3461], dtype=int32),
#  array([ 218, 3262], dtype=int32),
#  array([487, 599], dtype=int32),
#  array([645, 346], dtype=int32),
#  array([  19, 1733], dtype=int32),
#  array([ 255, 1497], dtype=int32),
#  array([1067,  564], dtype=int32),
#  array([1453,  805], dtype=int32),
#  array([  19, 2164], dtype=int32),
#  array([ 243, 1940], dtype=int32),
#  array([670, 296], dtype=int32),
#  array([735, 192], dtype=int32),
#  array([ 602, 1822], dtype=int32),
#  array([ 874, 1550], dtype=int32),
#  array([1210,  690], dtype=int32),
#  array([1287,  738], dtype=int32),
#  array([1762, 3097], dtype=int32),
#  array([1762, 3047], dtype=int32),
#  array([ 120, 1171], dtype=int32),
#  array([ 186, 1105], dtype=int32),
#  array([ 938, 2923], dtype=int32),
#  array([ 938, 2841], dtype=int32),
#  array([ 908, 2436], dtype=int32),
#  array([ 908, 2330], dtype=int32),
#  array([1379, 2508], dtype=int32),
#  array([1379, 2344], dtype=int32),
#  array([1051,  563], dtype=int32),
#  array([1238,  680], dtype=int32),
#  array([  21, 3024], dtype=int32),
#  array([ 241, 2804], dtype=int32),
#  array([1282,  713], dtype=int32),
#  array([1386,  778], dtype=int32),
#  array([1722, 3260], dtype=int32),
#  array([1723, 3201], dtype=int32),
#  array([ 897, 3352], dtype=int32),
#  array([ 897, 2725], dtype=int32),
#  array([  19, 1256], dtype=int32),
#  array([ 127, 1148], dtype=int32),
#  array([ 962, 2764], dtype=int32),
#  array([1150, 2764], dtype=int32),
#  array([ 105, 1190], dtype=int32),
#  array([ 263, 1032], dtype=int32),
#  array([1405, 2377], dtype=int32),
#  array([1733, 2377], dtype=int32),
#  array([1168,  628], dtype=int32),
#  array([1456,  808], dtype=int32),
#  array([ 777, 1321], dtype=int32),
#  array([ 849, 1371], dtype=int32),
#  array([ 921, 3104], dtype=int32),
#  array([ 921, 2747], dtype=int32),
#  array([ 122, 1163], dtype=int32),
#  array([ 188, 1097], dtype=int32),
#  array([241, 950], dtype=int32),
#  array([ 440, 1075], dtype=int32),
#  array([  19, 2599], dtype=int32),
#  array([ 245, 2373], dtype=int32),
#  array([1351, 1382], dtype=int32),
#  array([1780, 1382], dtype=int32),
#  array([1763, 3348], dtype=int32),
#  array([1764, 3285], dtype=int32),
#  array([  19, 2178], dtype=int32),
#  array([ 165, 2032], dtype=int32),
#  array([1405, 2614], dtype=int32),
#  array([1735, 2614], dtype=int32),
#  array([ 504, 2772], dtype=int32),
#  array([ 675, 2772], dtype=int32),
#  array([1760, 2594], dtype=int32),
#  array([1760, 2649], dtype=int32),
#  array([1071,  566], dtype=int32),
#  array([1453,  804], dtype=int32),
#  array([ 604, 1824], dtype=int32),
#  array([ 858, 1570], dtype=int32),
#  array([ 927, 3325], dtype=int32),
#  array([ 929, 3273], dtype=int32),
#  array([688, 334], dtype=int32),
#  array([766, 384], dtype=int32),
#  array([ 532, 1321], dtype=int32),
#  array([ 769, 1469], dtype=int32),
#  array([647, 299], dtype=int32),
#  array([862, 433], dtype=int32),
#  array([ 383, 3488], dtype=int32),
#  array([ 589, 3282], dtype=int32),
#  array([1405, 2768], dtype=int32),
#  array([1735, 2768], dtype=int32),
#  array([1068,  558], dtype=int32),
#  array([1398,  764], dtype=int32),
#  array([ 689, 2156], dtype=int32),
#  array([ 907, 1938], dtype=int32),
#  array([ 662, 3045], dtype=int32),
#  array([ 896, 2811], dtype=int32),
#  array([1335, 1826], dtype=int32),
#  array([1452, 1899], dtype=int32),
#  array([ 917, 3123], dtype=int32),
#  array([ 917, 3065], dtype=int32),
#  array([ 691, 2158], dtype=int32),
#  array([ 907, 1942], dtype=int32),
#  array([256, 938], dtype=int32),
#  array([468, 599], dtype=int32),
#  array([1060,  576], dtype=int32),
#  array([1230,  682], dtype=int32),
#  array([ 103, 1198], dtype=int32),
#  array([310, 991], dtype=int32),
#  array([1764, 2991], dtype=int32),
#  array([1764, 2935], dtype=int32),
#  array([  19, 2174], dtype=int32),
#  array([ 163, 2030], dtype=int32),
#  array([1743, 3100], dtype=int32),
#  array([1744, 3033], dtype=int32),
#  array([1778, 2429], dtype=int32),
#  array([1778, 2331], dtype=int32),
#  array([439, 656], dtype=int32),
#  array([629, 775], dtype=int32),
#  array([1390,  910], dtype=int32),
#  array([1390,  834], dtype=int32),
#  array([  21, 3028], dtype=int32),
#  array([ 243, 2806], dtype=int32),
#  array([ 981, 1051], dtype=int32),
#  array([1220, 1200], dtype=int32),
#  array([ 939, 3338], dtype=int32),
#  array([1778, 3338], dtype=int32),
#  array([631, 328], dtype=int32),
#  array([852, 466], dtype=int32),
#  array([1766, 2107], dtype=int32),
#  array([1766, 1752], dtype=int32),
#  array([ 924, 3117], dtype=int32),
#  array([1180, 3117], dtype=int32),
#  array([ 938, 2381], dtype=int32),
#  array([1113, 2381], dtype=int32),
#  array([1639,  924], dtype=int32),
#  array([1780, 1012], dtype=int32),
#  array([ 664, 3047], dtype=int32),
#  array([ 906, 2805], dtype=int32),
#  array([452, 666], dtype=int32),
#  array([627, 776], dtype=int32),
#  array([  19, 3457], dtype=int32),
#  array([ 216, 3260], dtype=int32),
#  array([1405, 2766], dtype=int32),
#  array([1735, 2766], dtype=int32),
#  array([1467, 1395], dtype=int32),
#  array([1639, 1395], dtype=int32),
#  array([  88, 1217], dtype=int32),
#  array([ 247, 1058], dtype=int32),
#  array([232, 982], dtype=int32),
#  array([ 639, 1237], dtype=int32),
#  array([1882, 1661], dtype=int32),
#  array([1882, 1404], dtype=int32),
#  array([ 417, 1092], dtype=int32),
#  array([ 478, 1129], dtype=int32),
#  array([1771, 1791], dtype=int32),
#  array([1771, 1847], dtype=int32),
#  array([1756, 2108], dtype=int32),
#  array([1756, 1874], dtype=int32),
#  array([ 960, 1871], dtype=int32),
#  array([1113, 1871], dtype=int32),
#  array([1734, 3340], dtype=int32),
#  array([1734, 3191], dtype=int32),
#  array([1404, 2612], dtype=int32),
#  array([1732, 2612], dtype=int32),
#  array([1771, 3238], dtype=int32),
#  array([1771, 3294], dtype=int32),
#  array([ 915, 3323], dtype=int32),
#  array([ 915, 3218], dtype=int32),
#  array([1123,  623], dtype=int32),
#  array([1178,  658], dtype=int32),
#  array([1203,  695], dtype=int32),
#  array([1258,  729], dtype=int32),
#  array([ 532, 1323], dtype=int32),
#  array([ 845, 1519], dtype=int32),
#  array([ 845, 1533], dtype=int32),
#  array([ 939, 1594], dtype=int32),
#  array([ 928, 3325], dtype=int32),
#  array([ 930, 3273], dtype=int32),
#  array([ 831, 2249], dtype=int32),
#  array([ 831, 1983], dtype=int32),
#  array([1634,  942], dtype=int32),
#  array([1708,  990], dtype=int32),
#  array([ 574, 1361], dtype=int32),
#  array([ 869, 1545], dtype=int32),
#  array([1334, 1828], dtype=int32),
#  array([1452, 1901], dtype=int32),
#  array([ 908, 3192], dtype=int32),
#  array([ 908, 3116], dtype=int32),
#  array([1780, 2121], dtype=int32),
#  array([1780, 1642], dtype=int32),
#  array([ 935, 2760], dtype=int32),
#  array([ 935, 2702], dtype=int32),
#  array([1381, 3097], dtype=int32),
#  array([1382, 3036], dtype=int32),
#  array([625, 332], dtype=int32),
#  array([842, 467], dtype=int32),
#  array([1378,  765], dtype=int32),
#  array([1430,  797], dtype=int32),
#  array([ 938, 2045], dtype=int32),
#  array([ 938, 1806], dtype=int32),
#  array([1384, 3060], dtype=int32),
#  array([1740, 3060], dtype=int32),
#  array([  21, 1336], dtype=int32),
#  array([  21, 1233], dtype=int32),
#  array([ 769, 3337], dtype=int32),
#  array([ 895, 3337], dtype=int32),
#  array([216, 968], dtype=int32),
#  array([ 480, 1133], dtype=int32),
#  array([648, 315], dtype=int32),
#  array([843, 442], dtype=int32),
#  array([1732, 2420], dtype=int32),
#  array([1733, 2345], dtype=int32),
#  array([244, 981], dtype=int32),
#  array([416, 706], dtype=int32),
#  array([ 960, 1940], dtype=int32),
#  array([ 960, 1854], dtype=int32),
#  array([647, 298], dtype=int32),
#  array([858, 430], dtype=int32),
#  array([1766, 3276], dtype=int32),
#  array([1766, 3221], dtype=int32),
#  array([232, 956], dtype=int32),
#  array([ 498, 1123], dtype=int32),
#  array([1632, 2047], dtype=int32),
#  array([1632, 1963], dtype=int32),
#  array([1753, 3101], dtype=int32),
#  array([1753, 3032], dtype=int32),
#  array([  19, 1747], dtype=int32),
#  array([ 165, 1601], dtype=int32),
#  array([1395, 2507], dtype=int32),
#  array([1395, 2392], dtype=int32),
#  array([ 989, 2552], dtype=int32),
#  array([ 989, 2488], dtype=int32),
#  array([1381, 1875], dtype=int32),
#  array([1732, 1875], dtype=int32),
#  array([1755, 1182], dtype=int32),
#  array([1757, 1035], dtype=int32),
#  array([ 981, 1053], dtype=int32),
#  array([1220, 1202], dtype=int32),
#  array([832, 936], dtype=int32),
#  array([ 944, 1011], dtype=int32),
#  array([1163,  628], dtype=int32),
#  array([1455,  810], dtype=int32),
#  array([  19, 2193], dtype=int32),
#  array([  19, 2013], dtype=int32),
#  array([1426, 1873], dtype=int32),
#  array([1735, 1873], dtype=int32),
#  array([ 217, 1064], dtype=int32),
#  array([299, 982], dtype=int32),
#  array([1357, 1928], dtype=int32),
#  array([1357, 1799], dtype=int32),
#  array([1756, 3092], dtype=int32),
#  array([1758, 3032], dtype=int32),
#  array([ 639, 2197], dtype=int32),
#  array([ 908, 2197], dtype=int32),
#  array([ 946, 2776], dtype=int32),
#  array([ 949, 2708], dtype=int32),
#  array([665, 289], dtype=int32),
#  array([722, 197], dtype=int32),
#  array([ 532, 1322], dtype=int32),
#  array([ 605, 1368], dtype=int32),
#  array([1050,  563], dtype=int32),
#  array([1445,  820], dtype=int32),
#  array([1384, 3053], dtype=int32),
#  array([1792, 3053], dtype=int32),
#  array([1043, 3128], dtype=int32),
#  array([1413, 3128], dtype=int32),
#  array([1735, 1928], dtype=int32),
#  array([1735, 1863], dtype=int32),
#  array([ 333, 1020], dtype=int32),
#  array([ 546, 1153], dtype=int32),
#  array([1189,  661], dtype=int32),
#  array([1263,  707], dtype=int32),
#  array([1732, 2611], dtype=int32),
#  array([1733, 2557], dtype=int32),
#  array([ 899, 2403], dtype=int32),
#  array([ 899, 2344], dtype=int32),
#  array([1195, 3115], dtype=int32),
#  array([1368, 3115], dtype=int32),
#  array([1778, 2810], dtype=int32),
#  array([1778, 2477], dtype=int32),
#  array([631, 326], dtype=int32),
#  array([852, 464], dtype=int32),
#  array([1384, 3066], dtype=int32),
#  array([1741, 3066], dtype=int32),
#  array([1051,  577], dtype=int32),
#  array([1426,  811], dtype=int32),
#  array([ 381, 3486], dtype=int32),
#  array([ 590, 3277], dtype=int32),
#  array([  19, 2609], dtype=int32),
#  array([ 143, 2485], dtype=int32),
#  array([1769, 1717], dtype=int32),
#  array([1769, 1773], dtype=int32),
#  array([232, 975], dtype=int32),
#  array([ 443, 1107], dtype=int32),
#  array([1723, 3273], dtype=int32),
#  array([1724, 3216], dtype=int32),
#  array([ 704, 1714], dtype=int32),
#  array([ 888, 1530], dtype=int32),
#  array([ 336, 1256], dtype=int32),
#  array([ 471, 1121], dtype=int32),
#  array([503, 715], dtype=int32),
#  array([620, 788], dtype=int32),
#  array([ 348, 1031], dtype=int32),
#  array([ 515, 1136], dtype=int32),
#  ...]

# %%
len(pts)
# Out:
# 1948

# %%
output_with_pts = cv.cvtColor(no_details.astype(np.uint8).copy(), cv.COLOR_GRAY2BGR)

for pt in pts:
    cv.circle(output_with_pts, (int(pt[0]), int(pt[1])), 10, (0, 0, 255), -1)
cv.imwrite("IMAGES/pts.png", output_with_pts)
# Out:
# True

# %%
def equal_pts(p1, p2):
    return p1[0] == p2[0] and p1[1] == p2[1]

to_delete = []
for pt in pts:
    # current = None
    close = 0
    for pt2 in pts:
        if equal_pts(pt, pt2):
            continue
        if np.linalg.norm(pt - pt2) < 50:
            close += 1
    if close < 3:
        to_delete.append(pt)

print(to_delete)
for pt in to_delete:
    pts = list(filter(lambda p: not equal_pts(p, pt), pts))
# Out:
# [array([1769, 3416], dtype=int32), array([ 674, 3346], dtype=int32), array([1622, 1246], dtype=int32), array([ 675, 3348], dtype=int32), array([1624, 1700], dtype=int32), array([ 101, 3235], dtype=int32), array([ 675, 2774], dtype=int32), array([ 829, 1739], dtype=int32), array([ 831, 2398], dtype=int32), array([1885, 2350], dtype=int32), array([1885, 2092], dtype=int32), array([ 831, 1727], dtype=int32), array([ 125, 2353], dtype=int32), array([ 814, 2171], dtype=int32), array([ 816, 2173], dtype=int32), array([ 123, 2351], dtype=int32), array([ 819, 1735], dtype=int32), array([ 124, 2781], dtype=int32), array([ 103, 3237], dtype=int32), array([ 700, 2726], dtype=int32), array([ 205, 2690], dtype=int32), array([ 207, 2692], dtype=int32), array([ 314, 2571], dtype=int32), array([ 205, 3125], dtype=int32), array([ 727, 2272], dtype=int32), array([ 126, 2783], dtype=int32), array([ 626, 2379], dtype=int32), array([ 303, 2151], dtype=int32), array([ 203, 3123], dtype=int32), array([ 628, 2381], dtype=int32), array([ 702, 2728], dtype=int32), array([ 212, 2256], dtype=int32), array([ 210, 2254], dtype=int32), array([ 725, 2270], dtype=int32), array([1130, 2371], dtype=int32), array([ 316, 2573], dtype=int32), array([ 424, 3036], dtype=int32), array([ 628, 1946], dtype=int32), array([ 630, 1948], dtype=int32), array([ 304, 2154], dtype=int32), array([ 297, 3019], dtype=int32), array([ 128, 1919], dtype=int32), array([ 530, 1627], dtype=int32), array([ 380, 2926], dtype=int32), array([ 619, 2821], dtype=int32), array([ 528, 1625], dtype=int32), array([ 407, 2472], dtype=int32), array([ 412, 2036], dtype=int32), array([ 460, 1703], dtype=int32), array([ 519, 2500], dtype=int32), array([1391, 2686], dtype=int32), array([ 126, 1917], dtype=int32), array([ 617, 2819], dtype=int32), array([ 517, 2933], dtype=int32), array([ 299, 3021], dtype=int32), array([ 379, 3358], dtype=int32), array([ 405, 2470], dtype=int32), array([ 585, 1091], dtype=int32), array([ 462, 1705], dtype=int32), array([ 410, 2034], dtype=int32), array([ 229, 1804], dtype=int32), array([ 515, 2931], dtype=int32), array([ 314, 1713], dtype=int32), array([ 482, 2818], dtype=int32), array([ 436, 2589], dtype=int32), array([ 382, 2928], dtype=int32), array([ 480, 2816], dtype=int32), array([ 494, 2371], dtype=int32), array([ 440, 2158], dtype=int32), array([ 422, 3034], dtype=int32), array([ 337, 1836], dtype=int32), array([ 517, 2498], dtype=int32), array([ 363, 1383], dtype=int32), array([ 311, 1712], dtype=int32), array([ 438, 2591], dtype=int32), array([ 129, 1487], dtype=int32), array([ 989, 2344], dtype=int32), array([ 361, 1381], dtype=int32), array([ 231, 1806], dtype=int32), array([ 381, 3360], dtype=int32), array([ 339, 1838], dtype=int32), array([1883, 2350], dtype=int32), array([1883, 2102], dtype=int32), array([ 438, 2156], dtype=int32), array([ 496, 2373], dtype=int32), array([ 245, 1942], dtype=int32), array([ 127, 1485], dtype=int32), array([ 474, 3257], dtype=int32), array([ 472, 3255], dtype=int32), array([1780, 3416], dtype=int32), array([ 587, 2699], dtype=int32), array([ 829, 2398], dtype=int32), array([ 783, 3064], dtype=int32), array([ 577, 3144], dtype=int32), array([ 785, 3066], dtype=int32), array([1623, 1847], dtype=int32), array([1697, 1773], dtype=int32), array([ 328, 2276], dtype=int32), array([ 257, 1499], dtype=int32), array([ 325, 3141], dtype=int32), array([ 589, 2266], dtype=int32), array([ 991, 2344], dtype=int32), array([ 697, 3160], dtype=int32), array([ 591, 2268], dtype=int32), array([ 589, 2701], dtype=int32), array([ 328, 2711], dtype=int32), array([ 330, 2278], dtype=int32), array([1759, 2214], dtype=int32), array([ 989, 3128], dtype=int32), array([1517, 1374], dtype=int32), array([1467, 1393], dtype=int32), array([ 327, 3143], dtype=int32), array([ 699, 3162], dtype=int32), array([ 241, 1365], dtype=int32), array([ 239, 1363], dtype=int32), array([1297, 2405], dtype=int32), array([1526, 2405], dtype=int32), array([1082, 2407], d ...

# %%
len(pts)
# Out:
# 1678

# %%
def determinant(a11, a12, a21, a22):
    return a11 * a22 - a21 * a12


def get_abc(line):  # assumes numpy
    p1 = np.array(line[0:2], dtype=np.int64)
    p2 = np.array(line[2:4], dtype=np.int64)
    a = p1[1] - p2[1]
    b = p2[0] - p1[0]
    c = - a * p1[0] - b * p1[1]
    return a, b, c


def line_intersection(line1, line2):
    a1, b1, c1 = get_abc(line1)
    a2, b2, c2 = get_abc(line2)

    det = determinant(a1, b1, a2, b2)
    if det == 0: # ignore equal
        return None

    return np.array((
        determinant(-c1, b1, -c2, b2), 
        determinant(a1, -c1, a2, -c2)
    )) / det


def point_in_segment(p, seg):
    # assumes that p is on the line
    return (
            min(seg[0], seg[2]) <= p[0] <= max(seg[0], seg[2])
    and
            min(seg[1], seg[3]) <= p[1] <= max(seg[1], seg[3])
    )

def segment_intersection(seg1, seg2):
    # find line intersection, check that it is inside both segments
    potential = line_intersection(seg1, seg2)
    # print(potential)
    if potential is None:
        return None
    
    # if potential[1] < 0:
    #     print(seg1, seg2, potential)
    #     print()
    #     print()
    #     print()
    #     return
    if not point_in_segment(potential, seg1) or not point_in_segment(potential, seg2):
        return None
    return potential

# %%
# points = []
# # for i in range(len(found_segs)):
# #     for j in range(len(found_segs)):
# #         if i == j:
# #             continue
# #         intersection = segment_intersection(found_segs[i], found_segs[j])
# #         if intersection is not None:
# #             points.append(intersection)
# 
# for s in found_segs:
#     points.append(s[:2])
#     points.append(s[2:4])

# %%
# pts = np.sort(pts, 0)
# list(pts)

# %%
from concave_hull import concave_hull, concave_hull_indexes

# %%
concave = concave_hull(pts, concavity=3)

# %%
# list(np.sort(concave, 0))

# %%
len(pts), len(concave)
# Out:
# (1678, 207)

# %%
output_with_concave = cv.cvtColor(no_details.astype(np.uint8).copy(), cv.COLOR_GRAY2BGR)

for i in range(len(concave)):
    # print(i, j)
    cv.line(output_with_concave, concave[i - 1], concave[i], (0, 0, 255), 3)
    cv.circle(output_with_concave, concave[i - 1], 10, (255, 0, 0), -1)
    cv.circle(output_with_concave, concave[i], 10, (255, 0, 0), -1)
    # output_with_concave[j][i] = (0, 0, 255) # cause x and y

cv.imwrite("IMAGES/concave.png", output_with_concave)
# Out:
# True
